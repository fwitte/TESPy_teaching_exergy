# %% [markdown]
# (intro_fundamentals)=
#
# - Übersetzen
# - Chemische Exergie beschreiben
#
# # Fundamentals of Exergy Analysis
#
# ## Introduction
#
# Exergy is bound to mass flow or to massless energy transfer such as heat transfer or power. The transport of exergy
# with mass can be further splitted into four different shares according to eq. {eq}`exergy-massflow`, i.e.:
#
# - physical {math}`e^\text{PH}`,
# - chemical {math}`e^\text{CH}`,
# - kinetic {math}`e^\text{KN}` and
# - potential {math}`e^\text{PT}`.
#
# In thermal engineering kinetic and potential energy can usually be neglected, simplifying the respective equation:
#
# ```{math}
# :label: exergy-massflow
# \dot E=\dot m \left(e^\text{PH}+e^\text{CH}+\cancel{e^\text{KN}}+\cancel{e^\text{PT}}\right)
# ```
#
# For heat, the share of exergy depends on the temperature level of the ambient and the temperature level of the heat:
#
# ```{math}
# :label: exergy-heat
# \dot E_{\text{q,}j}=\left(1-\frac{T_0}{T_j}\right)\cdot \dot Q_j
# ```
#
# Work is pure exergy:
#
# ```{math}
# :label: exergy-work
# \dot E_{\text{w,}i} = \dot W_{\text{t,}i}
# ```
#
# ### Physical Exergy
#
# Physical exergy defines the maximum work that can be generated by a mass flow when enthalpy and entropy of the flow
# change to the ambient state `0`.
#
# ```{math}
# :label: physical-exergy-total
# e^\mathrm{PH} = \left( h - h \left( p_0, T_0 \right) \right) -
# T_0 \cdot \left(s - s\left(p_0, T_0\right)\right)
# ```
#
# Following the definitions in {cite}`Morosuk2019`, phyical exergy can be further splitted into two shares:
#
# - the mechanical exergy, eq. {eq}`mechanical-exergy` and
# - the thermal exergy, eq. {eq}`thermal-exergy`.
#
# The physical exergy is the sum of both shares eq. {eq}`physical-exergy`.
#
# ```{math}
# :label: thermal-exergy
# e^\mathrm{T} = \left( h - h \left( p, T_0 \right) \right) -
# T_0 \cdot \left(s - s\left(p, T_0\right)\right)
# ```
#
# ```{math}
# :label: mechanical-exergy
# e^\mathrm{M}=\left(h\left(p,T_0\right)-h\left(p_0,T_0\right)\right)
# -T_0\cdot\left(s\left(p, T_0\right)-s\left(p_0,T_0\right)\right)
# ```
#
# ```{math}
# :label: physical-exergy
# e^\mathrm{PH} = e^\mathrm{T} + e^\mathrm{M}
# ```
#
# ### Chemical Exergy
#
# ```{math}
# :label: chemical-exergy-general
# e^\text{CH} = \left(\sum x_i M_i\right)^{-1}\cdot\left(\sum x_i \bar{e}_i^\text{CH} + \bar{R} T_0\sum x_i \ln
# x_i\right)
# ```
#
# ```{math}
# :label: chemical-exergy-specific
# e^\text{CH}=\left(\sum x_i M_i\right)^{-1}\cdot\left(x_\text{gas}\left(\sum x'_i \bar{e}^\text{CH}_i+\bar{R} T_0
# \sum x'_i \ln{x'_i}\right) + x_{\text{H}_2\text{O}_\text{(l)}}\bar{e}^\text{CH}_{\text{H}_2\text{O}_\text{(l)}}
# \right)
# ```
#
# ## Exergy Analyses
#
# {ref}`Figure 1 <exergy-system>` shows an abstract thermodynamic system and the exergy transported over the system's
# boundary. Based on that, we can define an exergy balance to analyse the system, taking into account exergy transferred
# to or from the system. These can be heat (eq. {eq}`exergy-heat`) and power (eq. {eq}`exergy-work`), incoming
# {math}`\dot E_{in}`and outgoing massflows {math}`\dot E_{out}` (eq. {eq}`exergy-massflow`) as well as the destruction
# of exergy {math}`\dot E_\text{D}` happening in all of the system's components.
#
#  ```{math}
# :label: ex-bilanz-stat
# 0=\sum\limits_{j}\dot E_{\text{q,}j}+
# \sum\limits_{i}\dot E_{\text{w,}i} + \sum\limits_{in}\dot E_{in}-\sum\limits_{out}\dot E_{out} -\dot E_\text{D}
# ```
#
# ```{figure} /figures/exergy-system.svg
# ---
# name: exergy-system
# ---
# Overview of the exergy balance of a thermodynamic system {cite}`Witte2022`.
# ```
#
# Furthermore, it is possible to define balance equations for each of the system's components {math}`k`. The exergy
# destruction can then be calculated as the difference between fuel exergy {math}`E_{\text{F,}k}` and the product exergy
# {math}`E_{\text{P,}k}`.
#
# ```{math}
# :label: ex-d-k
# \dot E_{\text{D,}k}=\dot E_{\text{F,}k}-\dot E_{\text{P,}k}
# ```
#
# Der exergetische Wirkungsgrad ergibt sich aus dem bekannten Nutzen-Aufwand-Verhältnis.
#
# ```{math}
# :label: ex-eff-k
# \varepsilon_k=\frac{\dot E_{\text{P,}k}}{\dot E_{\text{F,}k}}
# ```
#
# Die Exergievernichtung des Gesamtprozesses ergibt sich aus der Summe der Exergievernichtungen aller Komponenten. Alle Ströme die ungenutzt über die Bilanzgrenze gehen werden als Exergieverluste betrachtet. Die Exergiebilanz für ein Gesamtprozess (total) kann damit notiert werden.
#
# ```{math}
# :label: ex-tot
# \dot E_\text{F,tot}=\dot E_\text{P,tot}+\dot E_\text{D,tot}+\dot E_\text{L,tot}
# ```
#
# Der exergetisiche Wirkungsgrad des Gesamtprozesses ergibt sich analog zu \cref{eq:ex-eff-k}.
#
# ```{math}
# :label: ex-eff-tot
# \varepsilon_\text{tot}=\frac{\dot E_\text{P,tot}}{\dot E_\text{F,tot}}=1-\frac{\dot E_\text{D,tot}+\dot E_\text{L,tot}}{\dot E_\text{F,tot}}
# ```
#
# Da sich die Exergievernichtung des Gesamtprozesses aus den Beiträgen der einzelnen Komponenten zusammensetzt, kann der Einfluss der einzelnen Komponenten auf die Verringerung des Gesamtwirkungsgrad aufgezeigt werden. Der Exergievernichtungskoeffizient verbindet die Informationen aus den Komponenten und dem Gesamtprozess.
#
# ```{math}
#     :label: ex-koeff-y
# y_{\text{D,}k}=\frac{\dot E_{\text{D,}k}}{\dot E_\text{F,tot}}
# ```
